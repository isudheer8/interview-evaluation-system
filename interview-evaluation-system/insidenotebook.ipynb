# %%
from core.models.audio.dsp_stub import BasicDSP
from core.models.audio.asr_stub import FasterWhisperASR

dsp = BasicDSP()
asr = FasterWhisperASR(model_size="small")

audio = dsp.preprocess("data\samples\ind_acc_sam.wav")
text = asr.transcribe(audio)

print("Transcribed Text:", text)
# Out:
# Transcribed Text: It's been a long time since she last read Chekhov and because of that, she no longer  feels like the heroine of her own story.

# %% [markdown]
# Metrics testing

# %%
! python -m snchek
# Out:
# c:\Users\Sudheer\packages\python.exe: No module named snchek

# %%
! python experiments/evaluation/metrics.py
# Out:
# Traceback (most recent call last):
#   File "d:\Major Project\coding\interview-evaluation-system\experiments\evaluation\metrics.py", line 6, in <module>
#     from core.orchestration.interview_orchestrator import InterviewOrchestrator
# ModuleNotFoundError: No module named 'core'
